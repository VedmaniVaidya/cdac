# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = np.zeros((100, 100, 3))
#display the image
plt.imshow(img)

# %%
img = img+100
img = img/255
#display the image
plt.imshow(img)

# %%
img2 = np.zeros((100,100))
img2 = img2+255
#display the image
plt.imshow(img2)
