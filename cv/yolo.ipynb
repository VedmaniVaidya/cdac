# %%
import torch
import cv2
import torchvision
import numpy as np
import matplotlib.pyplot as plt

# %%
#yolo5 
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Using cache found in /home/dai/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-12-29 Python-3.11.5 torch-2.1.1+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
image = cv2.imread('./data/images/jungle.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
results = model(image)

# %%
#display the results in form of image
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=640x476>
