# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import PIL

# %%
img = cv2.imread('./images/dog.jpg')
img
# Out:
# array([[[123, 188, 166],
#         [123, 188, 166],
#         [124, 189, 167],
#         ...,
#         [117, 184, 163],
#         [116, 184, 161],
#         [115, 182, 161]],
#
#        [[123, 188, 166],
#         [123, 188, 166],
#         [124, 189, 167],
#         ...,
#         [117, 184, 163],
#         [117, 184, 163],
#         [116, 183, 162]],
#
#        [[123, 188, 166],
#         [124, 189, 167],
#         [124, 189, 167],
#         ...,
#         [118, 185, 164],
#         [118, 185, 164],
#         [117, 184, 163]],
#
#        ...,
#
#        [[ 59, 124,  99],
#         [ 60, 122, 100],
#         [ 61, 123, 101],
#         ...,
#         [ 69, 125, 120],
#         [ 67, 121, 121],
#         [ 66, 122, 117]],
#
#        [[ 57, 123,  98],
#         [ 57, 122,  97],
#         [ 58, 120,  98],
#         ...,
#         [ 71, 128, 120],
#         [ 69, 125, 120],
#         [ 71, 125, 118]],
#
#        [[ 56, 121,  99],
#         [ 56, 122,  97],
#         [ 57, 122,  97],
#         ...,
#         [ 71, 128, 119],
#         [ 71, 127, 122],
#         [ 72, 126, 121]]], dtype=uint8)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img.size
# Out:
# 481200

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img = plt.imread('./images/dog.jpg')
plt.imshow(img)

# %%
#take transpose of image using numpy
img = img.transpose(1,0,2)

# %%
img = cv2.imread('./images/dog.jpg')
cv2.imshow('dog', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from PIL import Image
img = Image.open('./images/dog.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=401x400>
